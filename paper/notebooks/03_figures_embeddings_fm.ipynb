# %% [markdown]
# # US-070 - Figuras y tablas de embeddings y modelos fundacionales
#
# - F3 UMAP de AlphaEarth (PNG real promovido).
# - T1 comparativa de FMs (AlphaEarth v1.1 vs Sentinel-2 vs FarSLIP fiel).
# - Transferencia FR->Cataluna (Sen4AgriNet, US-075): zero vs few-shot.
#
# F2 mapas AOI Italia = B-070-1 (requiere auth GEE). La celda de AOI se deja
# lista para completar con GEE; no se fabrica el mapa.

# %%
import structlog

structlog.configure(processors=[structlog.dev.ConsoleRenderer()])
from ml.report import paper_figures as pf
from ml.report import paper_tables as pt

# Seed fijo y estilo cientifico (CVPR/ISPRS) para reproducibilidad byte-a-byte.
pf.set_paper_style()
print("paper style aplicado, seed =", pf.PAPER_SEED)
# Out:
# paper style aplicado, seed =
# 17

# %%
# F3 UMAP AlphaEarth + transferencia FR->Cataluna
umap_src = pf.PROMOTED_FIGURES["umap_alphaearth"]
print("F3 umap:", pf.promote_png(umap_src, "umap_alphaearth"))
print("transfer FR->Cataluna:", pf.fig_transfer_catalonia())
# Out:
# paper_figure_saved
# png
# =
# paper\figures\us-070\umap_alphaearth.png
# stem
# =
# umap_alphaearth
# svg
# =
# paper\figures\us-070\umap_alphaearth.svg
# F3 umap:
# {'svg': WindowsPath('paper/figures/us-070/umap_alphaearth.svg'), 'png': WindowsPath('paper/figures/us-070/umap_alphaearth.png')}
# paper_figure_saved
# png
# =
# paper\figures\us-070\transfer_fr_catalonia.png
# stem
# =
# transfer_fr_catalonia
# svg
# =
# paper\figures\us-070\transfer_fr_catalonia.svg
# transfer FR->Cataluna:
# {'svg': WindowsPath('paper/figures/us-070/transfer_fr_catalonia.svg'), 'png': WindowsPath('paper/figures/us-070/transfer_fr_catalonia.png')}

# %%
# T1 comparativa de modelos fundacionales
from pathlib import Path
Path("paper/tables/us-070").mkdir(parents=True, exist_ok=True)
t1 = pt.build_fm_comparison_table()
Path("paper/tables/us-070/fm_comparison.tex").write_text(t1, encoding="utf-8")
print(t1)
# Out:
# \begin{table}
# \caption{Comparativa de modelos fundacionales. AlphaEarth = SATELLITE\_EMBEDDING/V1/ANNUAL, data v1.1, 64-dim, CC-BY-4.0. Sentinel-2 crudo 10 bandas y FarSLIP fiel (separabilidad por KMeans) como referencias. Cifras leidas de reports/ (sin hardcode).}
# \label{tab:fm_comparison}
# \begin{tabular}{lrrrrrr}
# \toprule
# Representacion & Modelo & n\_feat & F1-macro & F1-w & mIoU & t (s) \\
# \midrule
# Vector combinado (187 feat) & XGB & 185 & 0.4106 & 0.6922 & 0.3127 & 469.4 \\
# Vector combinado (187 feat) & RF & 185 & 0.3646 & 0.6571 & 0.2695 & 83.9 \\
# AlphaEarth 64-dim & XGB & 64 & 0.3523 & 0.6529 & 0.2576 & 275.1 \\
# AlphaEarth 64-dim & RF & 64 & 0.3275 & 0.6344 & 0.2360 & 56.8 \\
# Sentinel-2 crudo (10 bandas) & XGB & 10 & 0.2570 & 0.5634 & 0.1765 & 181.7 \\
# Sentinel-2 crudo (10 bandas) & RF & 10 & 0.2044 & 0.4948 & 0.1350 & 21.3 \\
# farslip\_pheno (fiel v2) & KMeans & 768 & 0.5551 & NaN & NaN & NaN \\
# alphaearth\_2019 & KMeans & 64 & 0.6446 & NaN & NaN & NaN \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ## B-070-1: F2 Mapas AOI Italia (pendiente, requiere auth GEE)
#
# Celda lista para completar tras autenticar Google Earth Engine y exportar la
# AOI real de Italia a GeoJSON. No se ejecuta aqui (sin auth GEE en este entorno);
# no se fabrica un mapa sintetico. Ver `docs/blockers/epic11-notas.md` (B-070-1).

# %%
# B-070-1 (NO ejecutar sin auth GEE): render de la AOI real de Italia.
# import geopandas as gpd, contextily as cx
# aoi = gpd.read_file('data/aoi/italy_aois.geojson')
# ax = aoi.to_crs(3857).plot(facecolor='none', edgecolor='red')
# cx.add_basemap(ax)
# pf.save_fig_svg_png(ax.figure, 'aoi_italy')
print("B-070-1 pendiente: requiere auth GEE (ver blockers)")
# Out:
# B-070-1 pendiente: requiere auth GEE (ver blockers)
