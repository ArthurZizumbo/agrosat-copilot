# %% [markdown]
# # US-070 - Figuras y tablas del agente y LLMs
#
# Orquesta sobre `reports/agent_bench/**` (corrida real US-049).
#
# - F5 ejemplos conversacionales ES/EN (IT = B-070-4, AgroMind-IT US-068).
# - F7-LLM barplot de benchmark (Gemini vs Qwen reales).
# - T4 benchmark LLMs (AgroMind-IT/ES = B-070-3, pendiente).
# - T5 ablacion de uso de herramientas (Gemini real; on-prem pendiente).
#
# Gemini 2.5-pro = reasoner FROZEN (patron Be My Eyes); Qwen3.5-35B-A3B vLLM
# GPTQ-Int4 single-GPU = variante on-prem (soberania de datos).

# %%
import structlog

structlog.configure(processors=[structlog.dev.ConsoleRenderer()])
from ml.report import paper_figures as pf
from ml.report import paper_tables as pt

# Seed fijo y estilo cientifico (CVPR/ISPRS) para reproducibilidad byte-a-byte.
pf.set_paper_style()
print("paper style aplicado, seed =", pf.PAPER_SEED)
# Out:
# paper style aplicado, seed =
# 17

# %%
# F7-LLM barplot + F5 ejemplos conversacionales ES/EN reales
print("F7-LLM:", pf.fig_llm_benchmark_barplot())
# F5: IT pendiente (B-070-4, AgroMind-IT US-068)
print("F5 conversational ES/EN:", pf.export_conversational_examples())
# Out:
# paper_figure_saved
# png
# =
# paper\figures\us-070\llm_benchmark_barplot.png
# stem
# =
# llm_benchmark_barplot
# svg
# =
# paper\figures\us-070\llm_benchmark_barplot.svg
# F7-LLM:
# {'svg': WindowsPath('paper/figures/us-070/llm_benchmark_barplot.svg'), 'png': WindowsPath('paper/figures/us-070/llm_benchmark_barplot.png')}
# conversational_examples_written
# n
# =
# 2
# path
# =
# paper\figures\us-070\conversational_examples.json
# F5 conversational ES/EN:
# paper\figures\us-070\conversational_examples.json

# %%
# T4 benchmark LLMs + T5 ablacion de tools
from pathlib import Path
Path("paper/tables/us-070").mkdir(parents=True, exist_ok=True)
t4 = pt.build_llm_benchmark_table()
Path("paper/tables/us-070/llm_benchmark.tex").write_text(t4, encoding="utf-8")
t5 = pt.build_tool_ablation_table()
Path("paper/tables/us-070/tool_ablation.tex").write_text(t5, encoding="utf-8")
print(t4)
print(t5)
# Out:
# \begin{table}
# \caption{Benchmark LLMs del copiloto: Gemini 2.5 Pro (reasoner frozen, patron Be My Eyes) vs Qwen3.5-35B-A3B vLLM GPTQ-Int4 on-prem (soberania de datos). Columna AgroMind-IT/ES pendiente (US-068/US-069, H100). Cifras leidas de us049\_system\_eval.json.}
# \label{tab:llm_benchmark}
# \begin{tabular}{lrrrrrr}
# \toprule
# Modelo & Tool-sel & Arg-match & Crop-match & Routing & Halluc-RAG & AgroMind IT/ES \\
# \midrule
# Gemini 2.5 Pro (frozen) & 0.5500 & 0.9545 & 0.9231 & 1.0000 & 0.1000 & \textit{pendiente} \\
# Qwen3.5-35B-A3B (on-prem) & 0.7500 & 0.9778 & 0.2308 & 0.3077 & 0.1000 & \textit{pendiente} \\
# \bottomrule
# \end{tabular}
# \end{table}
# \begin{table}
# \caption{Ablacion de uso de herramientas del agente ADK (corrida real Gemini, 20 escenarios). Variante on-prem Qwen pendiente (US-069, H100). Cifras leidas de us049\_system\_eval.json.}
# \label{tab:tool_ablation}
# \begin{tabular}{lrr}
# \toprule
# Dimension de uso de tools & Gemini & Qwen (on-prem) \\
# \midrule
# Llamada nativa a tool & 1.0000 & \textit{pendiente} \\
# Tasa de fallo de parseo & 0.0000 & \textit{pendiente} \\
# Exactitud de seleccion de tool & 0.5500 & \textit{pendiente} \\
# Coincidencia de argumentos & 0.9545 & \textit{pendiente} \\
# Tasa sin llamada & 0.0000 & \textit{pendiente} \\
# Crop grounding (match) & 0.9231 & \textit{pendiente} \\
# Routing accuracy & 1.0000 & \textit{pendiente} \\
# Faithfulness de crop & 1.0000 & \textit{pendiente} \\
# \bottomrule
# \end{tabular}
# \end{table}
