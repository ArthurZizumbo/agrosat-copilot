# %% [markdown]
# # US-070 - Figuras y tablas de ensambles y FarSLIP (EPIC 6)
#
# Orquesta sobre `reports/ensemble/**` y `reports/farslip/**`. Campeon:
# Stacking-5 (+FarSLIP). Ablacion de bandas completa (3 variantes) = B-070-5.
#
# - F8 mapa de error espacial (residuals blending).
# - T3 ensambles EPIC 6 (4 rubrica + E-a/E-b + grid FarSLIP).
# - Fx curva de ablacion FarSLIP (cardinalidad de clases).
# - Tx tabla de ablacion de bandas FarSLIP (lo materializado).

# %%
import structlog

structlog.configure(processors=[structlog.dev.ConsoleRenderer()])
from ml.report import paper_figures as pf
from ml.report import paper_tables as pt

# Seed fijo y estilo cientifico (CVPR/ISPRS) para reproducibilidad byte-a-byte.
pf.set_paper_style()
print("paper style aplicado, seed =", pf.PAPER_SEED)
# Out:
# paper style aplicado, seed =
# 17

# %%
# F8 mapa de error espacial + F6-ens confusion stacking
for stem in ["spatial_residuals", "confusion_stacking"]:
    print(stem, pf.promote_png(pf.PROMOTED_FIGURES[stem], stem))
# Out:
# paper_figure_saved
# png
# =
# paper\figures\us-070\spatial_residuals.png
# stem
# =
# spatial_residuals
# svg
# =
# paper\figures\us-070\spatial_residuals.svg
# spatial_residuals
# {'svg': WindowsPath('paper/figures/us-070/spatial_residuals.svg'), 'png': WindowsPath('paper/figures/us-070/spatial_residuals.png')}
# paper_figure_saved
# png
# =
# paper\figures\us-070\confusion_stacking.png
# stem
# =
# confusion_stacking
# svg
# =
# paper\figures\us-070\confusion_stacking.svg
# confusion_stacking
# {'svg': WindowsPath('paper/figures/us-070/confusion_stacking.svg'), 'png': WindowsPath('paper/figures/us-070/confusion_stacking.png')}

# %%
# Fx curva de ablacion FarSLIP recompuesta desde parcel_sweep.csv
print("Fx farslip_sweep:", pf.fig_farslip_sweep_curve())
# Out:
# paper_figure_saved
# png
# =
# paper\figures\us-070\farslip_sweep_curve.png
# stem
# =
# farslip_sweep_curve
# svg
# =
# paper\figures\us-070\farslip_sweep_curve.svg
# Fx farslip_sweep:
# {'svg': WindowsPath('paper/figures/us-070/farslip_sweep_curve.svg'), 'png': WindowsPath('paper/figures/us-070/farslip_sweep_curve.png')}

# %%
# T3 ensambles + Tx ablacion bandas FarSLIP
from pathlib import Path
Path("paper/tables/us-070").mkdir(parents=True, exist_ok=True)
t3 = pt.build_ensemble_table()
Path("paper/tables/us-070/ensembles_e6.tex").write_text(t3, encoding="utf-8")
tx = pt.build_farslip_band_ablation_table()
Path("paper/tables/us-070/farslip_band_ablation.tex").write_text(tx, encoding="utf-8")
print(t3)
print(tx)
# Out:
# \begin{table}
# \caption{Ensambles EPIC 6: 4 estrategias de rubrica (US-040), incrementales E-a/E-b (US-041/042) y grid FarSLIP (US-043). Campeon: Stacking-5 (+FarSLIP). Cifras leidas de reports/ensemble/metrics/.}
# \label{tab:ensembles_e6}
# \begin{tabular}{lrrr}
# \toprule
# Estrategia / fuente & F1-macro & Accuracy & Nota \\
# \midrule
# E3 Stacking (parcela) (elegido) & 0.7470 & 0.8490 & US-040 \\
# E4 Blending (parcela) & 0.7414 & 0.8618 & US-040 \\
# TSViT-pheno (individual) & 0.6253 & NaN & US-040 \\
# E1 Voting (pixel) & 0.6225 & 0.8090 & US-040 \\
# E2 Bagging (parcela) & 0.5864 & 0.7816 & US-040 \\
# TSViT-pheno-fullm (individual) & 0.6764 & NaN & mejor segmentador individual (baseline E-a) \\
# Stacking US-040 (E3) & 0.7470 & 0.8490 & mejor ensamble de US-040 (3 miembros densos+tabular sin Far... \\
# E-a fusion dual-head (alpha=0.05) & 0.2694 & 0.5873 & gain -0.407 vs TSViT: fusion ingenua 4-vs-18 clases DANA \\
# E-b stacking E-a + AlphaEarth & 0.3395 & 0.6937 & gain +0.156 vs E-a sola pero lejos del Stacking US-040 \\
# Stacking-5 +FarSLIP (US-043, campeon) & 0.7486 & 0.8495 & nuevo campeon: FarSLIP via stacking (ft-18 + zero-shot) +0.... \\
# Stacking-3 | tsvit-pheno (campeon US-040) & 0.7470 & 0.8490 & delta 0.0000 \\
# Stacking-5 (+FarSLIP) | tsvit-pheno (campeon US-040) & 0.7486 & 0.8495 & delta 0.0016 \\
# Blending-3 | tsvit-pheno (campeon US-040) & 0.7436 & 0.8629 & delta 0.0000 \\
# Blending-5 (+FarSLIP) | tsvit-pheno (campeon US-040) & 0.7319 & 0.8594 & delta -0.0117 \\
# Stacking-3 | tsvit-pheno-fullm (mejor individual) & 0.6359 & 0.7877 & delta 0.0000 \\
# Stacking-5 (+FarSLIP) | tsvit-pheno-fullm (mejor individual) & 0.6477 & 0.7935 & delta 0.0118 \\
# Blending-3 | tsvit-pheno-fullm (mejor individual) & 0.5651 & 0.7697 & delta 0.0000 \\
# Blending-5 (+FarSLIP) | tsvit-pheno-fullm (mejor individual) & 0.5866 & 0.7864 & delta 0.0215 \\
# \bottomrule
# \end{tabular}
# \end{table}
# \begin{table}
# \caption{Ablacion FarSLIP: barrido de cardinalidad de clases a nivel parcela y separabilidad FarSLIP fiel vs AlphaEarth (silhouette/F1-macro KMeans). Las 3 variantes de banda completas (rgb/nir-rgb/4band-pheno) requieren re-extraccion en H100 (B-070-5). Cifras leidas de reports/farslip/.}
# \label{tab:farslip_band_ablation}
# \begin{tabular}{lrrrr}
# \toprule
# n\_clases & macro-F1 & macro-IoU & bien resueltas & parcelas eval \\
# \midrule
# 4 & 0.7025 & 0.5547 & 4 & 1301 \\
# 6 & 0.4579 & 0.3120 & 2 & 1843 \\
# 8 & 0.4075 & 0.2657 & 3 & 2301 \\
# 10 & 0.3589 & 0.2288 & 3 & 2706 \\
# 12 & 0.3328 & 0.2071 & 1 & 3200 \\
# farslip\_pheno (fiel v2) & 0.5551 & 0.0120 & - & 567 \\
# alphaearth\_2019 & 0.6446 & 0.0145 & - & 567 \\
# \bottomrule
# \end{tabular}
# \end{table}
