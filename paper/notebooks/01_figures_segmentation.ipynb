# %% [markdown]
# # US-070 - Figuras y tablas de segmentacion (EPIC 5)
#
# Reproducible. Orquesta `ml.report.paper_figures` y `ml.report.paper_tables`
# sobre artefactos reales de `reports/segmentation/**`. Cifras leidas del
# artefacto, nunca hardcodeadas. Notas de bloqueos: `docs/blockers/epic11-notas.md`.
#
# - F4 curvas de entrenamiento TSViT (full-config H100 = B-070-2).
# - F6 matriz de confusion TSViT.
# - F7-seg barplot de benchmark fold-5 (re-score harness US-030).
# - T2 modelos individuales fold-5.
#
# AlphaEarth = SATELLITE_EMBEDDING/V1/ANNUAL v1.1; SegFormer = B0 RGB 3-banda;
# AnySat sustituye a Swin-UNETR (nunca entrenado).

# %%
import structlog

structlog.configure(processors=[structlog.dev.ConsoleRenderer()])
from ml.report import paper_figures as pf
from ml.report import paper_tables as pt

# Seed fijo y estilo cientifico (CVPR/ISPRS) para reproducibilidad byte-a-byte.
pf.set_paper_style()
print("paper style aplicado, seed =", pf.PAPER_SEED)
# Out:
# paper style aplicado, seed =
# 17

# %%
# F7-seg: barplot de benchmark recompuesto desde model_comparison_fold5.csv
print("F7-seg:", pf.fig_benchmark_barplot())
# Out:
# paper_figure_saved
# png
# =
# paper\figures\us-070\benchmark_barplot_fold5.png
# stem
# =
# benchmark_barplot_fold5
# svg
# =
# paper\figures\us-070\benchmark_barplot_fold5.svg
# F7-seg:
# {'svg': WindowsPath('paper/figures/us-070/benchmark_barplot_fold5.svg'), 'png': WindowsPath('paper/figures/us-070/benchmark_barplot_fold5.png')}

# %%
# F4 curvas TSViT y F6 confusion TSViT (PNG reales promovidos a SVG+PNG)
for stem in ["curves_tsvit", "confusion_tsvit", "per_class_iou_tsvit"]:
    print(stem, pf.promote_png(pf.PROMOTED_FIGURES[stem], stem))
# Out:
# paper_figure_saved
# png
# =
# paper\figures\us-070\curves_tsvit.png
# stem
# =
# curves_tsvit
# svg
# =
# paper\figures\us-070\curves_tsvit.svg
# curves_tsvit
# {'svg': WindowsPath('paper/figures/us-070/curves_tsvit.svg'), 'png': WindowsPath('paper/figures/us-070/curves_tsvit.png')}
# paper_figure_saved
# png
# =
# paper\figures\us-070\confusion_tsvit.png
# stem
# =
# confusion_tsvit
# svg
# =
# paper\figures\us-070\confusion_tsvit.svg
# confusion_tsvit
# {'svg': WindowsPath('paper/figures/us-070/confusion_tsvit.svg'), 'png': WindowsPath('paper/figures/us-070/confusion_tsvit.png')}
# paper_figure_saved
# png
# =
# paper\figures\us-070\per_class_iou_tsvit.png
# stem
# =
# per_class_iou_tsvit
# svg
# =
# paper\figures\us-070\per_class_iou_tsvit.svg
# per_class_iou_tsvit
# {'svg': WindowsPath('paper/figures/us-070/per_class_iou_tsvit.svg'), 'png': WindowsPath('paper/figures/us-070/per_class_iou_tsvit.png')}

# %%
# T2: modelos individuales EPIC 5 re-scoreados fold-5
from pathlib import Path
tex = pt.build_segmentation_table()
out = Path('paper/tables/us-070')
out.mkdir(parents=True, exist_ok=True)
(out / "segmentation_individual_fold5.tex").write_text(tex, encoding="utf-8")
print(tex)
# Out:
# \begin{table}
# \caption{Modelos individuales EPIC 5 re-scoreados con el harness unico de US-030 (fold-5, 18 clases contiguas, 128px NEAREST). SegFormer = B0 RGB 3-banda; AnySat sustituye a Swin-UNETR (nunca entrenado). Cifras leidas de model\_comparison\_fold5.csv.}
# \label{tab:segmentation_individual_fold5}
# \begin{tabular}{lrrrrrrr}
# \toprule
# Modelo & mIoU & F1-macro & Pix-acc & Kappa & Bal-acc & Bandas & Resize \\
# \midrule
# tsvit-pheno & 0.6139 & 0.7401 & 0.8637 & 0.8310 & 0.7183 & 10 & no \\
# segformer & 0.2715 & 0.3777 & 0.6395 & 0.5538 & 0.3756 & 3 & si \\
# deeplabv3plus & 0.2540 & 0.3614 & 0.6539 & 0.5676 & 0.3614 & 10 & no \\
# unet & 0.2056 & 0.2847 & 0.6394 & 0.5494 & 0.2972 & 10 & no \\
# anysat & 0.1684 & 0.2240 & 0.6994 & 0.5926 & 0.2288 & 10 & no \\
# utae & 0.1605 & 0.2240 & 0.6010 & 0.5080 & 0.2228 & 10 & no \\
# \bottomrule
# \end{tabular}
# \end{table}
